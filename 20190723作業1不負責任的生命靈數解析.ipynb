# %%
print("不負責任的生命靈數解析來囉～～")
name = input('請輸入您的大名：')
num = input('請輸入出生的西元年月日（共８碼）：' + '\n' + '（例如西元2019年1月23日，請輸入20190123）' + '\n')
plus = sum(map(int, str(num)))
mi = sum(map(int, str(plus)))

if mi <= 1:
    print('您的生命靈數為：'+ str(mi) + '\n' + '優點：獨立、積極、創造、領導、富創意與理解力，為人聰明，喜歡領導' + '\n' + '缺點：強勢、獨斷、浮躁、自私、懶散、吹牛、主觀意識強，我行我素，人際關係淡薄')
elif mi <= 2:
    print('您的生命靈數為：'+ str(mi) + '\n' + '優點：敏感、體貼、柔順、和諧、依賴、個性內斂，善於分工合作，重視群體關係，喜歡受到別人肯定' + '\n' + '缺點：情緒不定、優柔寡斷、難以捉摸、膚淺不安、容易因他人的意見而受到影響，不能忍耐孤獨')
elif mi <= 3:
    print('您的生命靈數為：'+ str(mi) + '\n' + '優點：行動、樂觀、自信、表現、社交、聰明機警，有創意，多具有藝術天份，表達能力強' + '\n' + '缺點：欺瞞、虛榮浮華、憤世嫉俗、渙散不集中、任性，多只依自己的喜好行事，容易好高騭遠')
elif mi <= 4:
    print('您的生命靈數為：'+ str(mi) + '\n' + '優點：忠誠、次序、效率、助人、自律、組織能力強，做事條理分明，目光敏銳，能迅速掌握重點' + '\n' + '缺點：獨斷獨行、心胸狹窄、容易緊張、不易妥協、固執，缺乏安全感，不敢承擔風險，因此容易讓機會溜走')
elif mi <= 5:
    print('您的生命靈數為：'+ str(mi) + '\n' + '優點：聰穎、冒險、適應強、多變化、學習快、能答善辯，口才極佳，熱情豪爽，講義氣，崇尚自由' + '\n' + '缺點：博而不精、持續力差、毫不在乎、索求無度、不喜歡受到束縛，容易放縱，容易得罪別人')
elif mi <= 6:
    print('您的生命靈數為：'+ str(mi) + '\n' + '優點：穩定、信賴、熱情、正義、奉獻、情感細膩，擅長人際間的交際，喜歡幫助他人，重承諾與責任' + '\n' + '缺點：缺乏自信、不切實際、好強爭辯、強行干涉、不理智時，常會做出錯誤的決定，付出不求回報時容易讓自己受傷')
elif mi <= 7:
    print('您的生命靈數為：'+ str(mi) + '\n' + '優點：內省、沉默、直覺、真理、理想、擅長鑽研事物，喜歡追求真理，精於算計，遇事理智' + '\n' + '缺點：冷漠、自大傲慢、自我放縱、鬼鬼祟祟、處事不夠圓滑，不容易被討好，容易到手的東西不會珍惜')
elif mi <= 8:
    print('您的生命靈數為：'+ str(mi) + '\n' + '優點：忠貞、持續、堅定、誠懇、照料、喜歡冒險刺激，有商業頭腦，喜歡追求權力，能即知即行' + '\n' + '缺點：唯物主義、無道德感、心高氣傲、排除他議、驕傲，對喜歡的東西有異常的執著，面對衝突時會勉強自己')
elif mi <= 9:
    print('您的生命靈數為：'+ str(mi) + '\n' + '優點：人性、啟發、活力、關懷、靈性、充滿生命力，能從創意之中獲得滿足感，處事隨機應變，見招拆招' + '\n' + '缺點：卑躬屈膝、毫無原則、善於批評、沒有耐性、行事不務實，意志不夠堅定，想像太過於力豐富則會變成天馬行空')
# Out:
# 不負責任的生命靈數解析來囉～～
# 請輸入您的大名：E. T.
# 請輸入出生的西元年月日（共８碼）：
# （例如西元2019年1月23日，請輸入20190123）
# 19930229
# 您的生命靈數為：8
# 優點：忠貞、持續、堅定、誠懇、照料、喜歡冒險刺激，有商業頭腦，喜歡追求權力，能即知即行
# 缺點：唯物主義、無道德感、心高氣傲、排除他議、驕傲，對喜歡的東西有異常的執著，面對衝突時會勉強自己
